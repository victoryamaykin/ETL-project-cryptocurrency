# %%
import json
import pandas as pd

json_file = '../GP2 ETL/convertcsv.json'

with open(json_file) as datafile:
    data = json.load(datafile)
json_file_df = pd.DataFrame(data)
json_file_df.head()
# Out:
#     close  close_ratio       date    high     low      market     name  \
# 0  134.21       0.5438  4/28/2013  135.98  132.10  1488566728  Bitcoin
# 1  144.54       0.7813  4/29/2013  147.49  134.00  1603768865  Bitcoin
# 2  139.00       0.3843  4/30/2013  146.93  134.05  1542813125  Bitcoin
# 3  116.99       0.2882   5/1/2013  139.89  107.72  1298954594  Bitcoin
# 4  105.21       0.3881   5/2/2013  125.60   92.28  1168517495  Bitcoin
#
#      open  ranknow     slug  spread symbol  volume
# 0  135.30        1  bitcoin    3.88    BTC       0
# 1  134.44        1  bitcoin   13.49    BTC       0
# 2  144.00        1  bitcoin   12.88    BTC       0
# 3  139.00        1  bitcoin   32.17    BTC       0
# 4  116.38        1  bitcoin   33.32    BTC       0

# %%
# take this json file and delete columns already listed:
# "Currency", "Date_open", "Open_price", "High", "Low", "Close_price", "Volume", "Market_Cap" 
json_file_df=json_file_df.drop(["name", "date", "open", "high", "low", "close", "volume", "market"], axis=1)
json_file_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-dd427a378cad> in <module>
#       1 # take this json file and delete columns already listed:
#       2 # "Currency", "Date_open", "Open_price", "High", "Low", "Close_price", "Volume", "Market_Cap"
# ----> 3 json_file_df=json_file_df.drop(["name", "date", "open", "high", "low", "close", "volume", "market"], axis=1)
#       4 json_file_df
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...

# %%
## "Currency", "Date_open", "Open_price", "High", "Low", "Close_price", "Volume", "Market_Cap"
